# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(0,100,0.1)

# %%
y=np.sin(x)

# %%
plt.plot(x,y)

# %% [markdown]
# Esto es una celda de markdown -> cell -> cell type -> markdown
